# %%
import logging
logging.getLogger("tensorflow").setLevel(logging.DEBUG)

import tensorflow as tf
from tensorflow import keras
import numpy as np
import pathlib
import joblib


import h5py
import pickle
import pandas as pd

import sys
# Out:
# 2023-10-22 07:37:48.829165: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.

# %%
with h5py.File('weights-96-5.346523.hdf5', 'r') as f:
    # Print all root level object names (aka keys) 
    # these can be group or dataset names 
    print("Keys: %s" % f.keys())
    # get first object name/key; may or may NOT be a group
    a_group_key = list(f.keys())[0]
    
    # get the object type for a_group_key: usually group or dataset
    print(type(f[a_group_key]))
# Out:
# Keys: <KeysViewHDF5 ['cg_id_0', 'cg_id_1', 'cg_id_2', 'cg_id_3', 'cg_id_4', 'cg_id_5', 'cg_reg_0', 'cg_reg_1', 'cg_reg_2', 'cg_reg_3', 'cg_reg_4', 'cg_reg_5', 'input_encoding_clic', 'node_encoding', 'normalization', 'output_decoding', 'top_level_model_weights']>
# <class 'h5py._hl.group.Group'>

# %%
# Open the HDF5 file
with h5py.File('weights-96-5.346523.hdf5', 'r') as file:
    # Loop through the keys and read the data
    for key in file.keys():
#         print(f"Key: {key}")

        # Check if the key refers to a group
        if isinstance(file[key], h5py.Group):
            # Access the group and print its keys
            group = file[key]
            print(f"Keys within {key}: {list(group.keys())}")

#             for subkey in group.keys():
#                 data = group[subkey][()]
#                 print(f"Data in {subkey}:")
#                 print(data)
# Out:
# Keys within cg_id_0: ['cg_id_0', 'cg_id_0_ffn_dist_dense_0', 'cg_id_0_ffn_dist_dense_1', 'cg_id_0_ffn_dist_dense_2', 'cg_id_0_ffn_dist_dense_3']
# Keys within cg_id_1: ['cg_id_1', 'cg_id_1_ffn_dist_dense_0', 'cg_id_1_ffn_dist_dense_1', 'cg_id_1_ffn_dist_dense_2', 'cg_id_1_ffn_dist_dense_3']
# Keys within cg_id_2: ['cg_id_2', 'cg_id_2_ffn_dist_dense_0', 'cg_id_2_ffn_dist_dense_1', 'cg_id_2_ffn_dist_dense_2', 'cg_id_2_ffn_dist_dense_3']
# Keys within cg_id_3: ['cg_id_3', 'cg_id_3_ffn_dist_dense_0', 'cg_id_3_ffn_dist_dense_1', 'cg_id_3_ffn_dist_dense_2', 'cg_id_3_ffn_dist_dense_3']
# Keys within cg_id_4: ['cg_id_4', 'cg_id_4_ffn_dist_dense_0', 'cg_id_4_ffn_dist_dense_1', 'cg_id_4_ffn_dist_dense_2', 'cg_id_4_ffn_dist_dense_3']
# Keys within cg_id_5: ['cg_id_5', 'cg_id_5_ffn_dist_dense_0', 'cg_id_5_ffn_dist_dense_1', 'cg_id_5_ffn_dist_dense_2', 'cg_id_5_ffn_dist_dense_3']
# Keys within cg_reg_0: ['cg_reg_0', 'cg_reg_0_ffn_dist_dense_0', 'cg_reg_0_ffn_dist_dense_1', 'cg_reg_0_ffn_dist_dense_2', 'cg_reg_0_ffn_dist_dense_3']
# Keys within cg_reg_1: ['cg_reg_1', 'cg_reg_1_ffn_dist_dense_0', 'cg_reg_1_ffn_dist_dense_1', 'cg_reg_1_ffn_dist_dense_2', 'cg_reg_1_ffn_dist_dense_3']
# Keys within cg_reg_2: ['cg_reg_2', 'cg_reg_2_ffn_dist_dense_0', 'cg_reg_2_ffn_dist_dense_1', 'cg_reg_2_ffn_dist_dense_2', 'cg_reg_2_ffn_dist_dense_3']
# Keys within cg_reg_3: ['cg_reg_3', 'cg_reg_3_ffn_dist_dense_0', 'cg_reg_3_ffn_dist_dense_1', 'cg_reg_3_ffn_dist_dense_2', 'cg_reg_3_ffn_dist_dense_3']
# Keys within cg_reg_4: ['cg_reg_4', 'cg_reg_4_ffn_dist_dense_0', 'cg_reg_4_ffn_dist_dense_1', 'cg_reg_4_ffn_dist_dense_2', 'cg_reg_4_ffn_dist_dense_3']
# Keys within cg_reg_5: ['cg_reg_5', 'cg_reg_5_ffn_dist_dense_0', 'cg_reg_5_ffn_dist_dense_1', 'cg_reg_5_ffn_dist_dense_2', 'cg_reg_5_ffn_dist_dense_3']
# Keys within input_encoding_clic: []
# Keys within node_encoding: ['node_encoding_dense_0', 'node_encoding_dense_1']
# Keys within normalization: ['normalization']
# Keys within output_decoding: ['ffn_charge_dense_0', 'ffn_charge_dense_1', 'ffn_cls_dense_0', 'ffn_cls_dense_1', 'ffn_energy_dense_0', 'ffn_energy_dense_1', 'ffn_eta_dense_0', 'ffn_eta_dense_1', 'ffn_phi_dense_0', 'ffn_phi_dense_1', 'ffn_pt_dense_0', 'ffn_pt_dense_1', 'output_decoding']
# Keys within top_level_model_weights: []

# %% [markdown]
# ## `Combining all`

# %%
import h5py
import tensorflow as tf
import sys
import numpy as np
import matplotlib.pyplot as plt

# Define a function to apply Float16 quantization
def float16_quantization(weights):
    return tf.dtypes.cast(weights, tf.float16)

# Define a function to get the size of an object in bytes
def get_size(obj):
    return sys.getsizeof(obj)

# Open the HDF5 file
with h5py.File('weights-96-5.346523.hdf5', 'r') as file:
    groups = ['cg_id_0', 'cg_id_1', 'cg_id_2', 'cg_id_3', 'cg_id_4', 'cg_id_5', 
              'cg_reg_0', 'cg_reg_1', 'cg_reg_2', 'cg_reg_3', 'cg_reg_4', 'cg_reg_5', 
              'output_decoding']

    total_original_bias_size = 0
    total_original_kernel_size = 0
    total_quantized_bias_size = 0
    total_quantized_kernel_size = 0

    for group in groups:
        print(f"Processing group: {group}")
        subgroup_names = file[group].keys()

        for subgroup_name in subgroup_names:
            try:
                # Access the subgroup
                subgroup = file[group][subgroup_name]

                # Load the weights (bias and kernel)
                bias = subgroup['bias:0'][()]  # Load bias
                kernel = subgroup['kernel:0'][()]  # Load kernel

                # Apply Float16 quantization to the weights
                float16_bias = float16_quantization(bias)
                float16_kernel = float16_quantization(kernel)

                # Print the sizes and reduction factors
                original_bias_size = get_size(bias)
                original_kernel_size = get_size(kernel)
                quantized_bias_size = get_size(float16_bias)
                quantized_kernel_size = get_size(float16_kernel)

                # Accumulate the sizes
                total_original_bias_size += original_bias_size
                total_original_kernel_size += original_kernel_size
                total_quantized_bias_size += quantized_bias_size
                total_quantized_kernel_size += quantized_kernel_size

                print(f"Output with Float 16 Quantization")
                print(f"=====================================")
                print(f"Subgroup Name: {subgroup_name}")
                print(f"Original Bias Size: {original_bias_size} bytes")
                print(f"Original Kernel Size: {original_kernel_size} bytes")
                print(f"Quantized Bias Size: {quantized_bias_size} bytes")
                print(f"Quantized Kernel Size: {quantized_kernel_size} bytes")
                print(f"Reduction Factor for Bias: {original_bias_size / quantized_bias_size}x")
                print(f"Reduction Factor for Kernel: {original_kernel_size / quantized_kernel_size}x")
                print('======================')
                print()

                # Plot histograms
                float16_kernel_array_proto = tf.make_tensor_proto(float16_kernel)
                float16_kernel_array = tf.make_ndarray(float16_kernel_array_proto)

                plt.figure(figsize=(10, 4))

                plt.subplot(1, 2, 1)
                plt.hist(kernel.flatten(), bins=200, color='skyblue')
                plt.xlabel('Value')
                plt.ylabel('Frequency')
                plt.title('Histogram before quantization')

                plt.subplot(1, 2, 2)
                plt.hist(float16_kernel_array.flatten(), bins=100, color='skyblue')
                plt.xlabel('Value')
                plt.ylabel('Frequency')
                plt.title('Histogram after quantization')

                plt.tight_layout()
                plt.show()

            except KeyError as e:
                print(f"Skipping subgroup {subgroup_name} due to KeyError: {e}")
                continue

    # Calculate total sizes
    total_original_size = total_original_bias_size + total_original_kernel_size
    total_quantized_size = total_quantized_bias_size + total_quantized_kernel_size

    # Print the total sizes and reduction factor
    print(f"Total Original Bias Size: {total_original_bias_size} bytes")
    print(f"Total Original Kernel Size: {total_original_kernel_size} bytes")
    print(f"Total Quantized Bias Size: {total_quantized_bias_size} bytes")
    print(f"Total Quantized Kernel Size: {total_quantized_kernel_size} bytes")
    print(f"Total Original Size: {total_original_size} bytes")
    print(f"Total Quantized Size: {total_quantized_size} bytes")
    print(f"Reduction Factor: {total_original_size / total_quantized_size}x")
# Out:
# Processing group: cg_id_0
# Skipping subgroup cg_id_0 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_0_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_0_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_0_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_0_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
# Processing group: cg_id_1
# Skipping subgroup cg_id_1 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_1_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_1_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_1_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_1_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
# Processing group: cg_id_2
# Skipping subgroup cg_id_2 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_2_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_2_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_2_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_2_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
# Processing group: cg_id_3
# Skipping subgroup cg_id_3 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_3_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_3_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_3_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_3_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
# Processing group: cg_id_4
# Skipping subgroup cg_id_4 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_4_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_4_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_4_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_4_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
# Processing group: cg_id_5
# Skipping subgroup cg_id_5 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_5_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_5_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_5_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_5_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
# Processing group: cg_reg_0
# Skipping subgroup cg_reg_0 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_0_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_0_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_0_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_0_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
# Processing group: cg_reg_1
# Skipping subgroup cg_reg_1 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_1_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_1_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_1_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_1_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
# Processing group: cg_reg_2
# Skipping subgroup cg_reg_2 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_2_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_2_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_2_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_2_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
# Processing group: cg_reg_3
# Skipping subgroup cg_reg_3 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_3_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_3_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_3_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_3_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
# Processing group: cg_reg_4
# Skipping subgroup cg_reg_4 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_4_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_4_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_4_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_4_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
# Processing group: cg_reg_5
# Skipping subgroup cg_reg_5 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_5_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_5_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_5_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_5_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
# Processing group: output_decoding
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_charge_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 131200 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 780.952380952381x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_charge_dense_1
# Original Bias Size: 124 bytes
# Original Kernel Size: 1664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 0.7380952380952381x
# Reduction Factor for Kernel: 9.904761904761905x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_cls_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 131200 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 780.952380952381x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_cls_dense_1
# Original Bias Size: 136 bytes
# Original Kernel Size: 3200 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 0.8095238095238095x
# Reduction Factor for Kernel: 19.047619047619047x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_energy_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 268416 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 1597.7142857142858x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_energy_dense_1
# Original Bias Size: 116 bytes
# Original Kernel Size: 640 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 0.6904761904761905x
# Reduction Factor for Kernel: 3.8095238095238093x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_eta_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 134272 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 799.2380952380952x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_eta_dense_1
# Original Bias Size: 116 bytes
# Original Kernel Size: 640 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 0.6904761904761905x
# Reduction Factor for Kernel: 3.8095238095238093x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_phi_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 134272 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 799.2380952380952x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_phi_dense_1
# Original Bias Size: 120 bytes
# Original Kernel Size: 1152 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 0.7142857142857143x
# Reduction Factor for Kernel: 6.857142857142857x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_pt_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 268416 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 1597.7142857142858x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_pt_dense_1
# Original Bias Size: 120 bytes
# Original Kernel Size: 1152 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 0.7142857142857143x
# Reduction Factor for Kernel: 6.857142857142857x
# ======================
# Skipping subgroup output_decoding due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Total Original Bias Size: 25212 bytes
# Total Original Kernel Size: 2655232 bytes
# Total Quantized Bias Size: 10080 bytes
# Total Quantized Kernel Size: 10080 bytes
# Total Original Size: 2680444 bytes
# Total Quantized Size: 20160 bytes
# Reduction Factor: 132.95853174603175x

# %% [markdown]
# ## int8 Qunatization

# %%
import h5py
import tensorflow as tf
import sys
import numpy as np
import matplotlib.pyplot as plt

# Define a function to apply Int8 quantization
def int8_quantization(weights):
    min_val = tf.reduce_min(weights)
    max_val = tf.reduce_max(weights)
    quantized_weights = tf.quantization.quantize(weights, min_val, max_val, tf.qint8)
    return quantized_weights


# Define a function to get the size of an object in bytes
def get_size(obj):
    return sys.getsizeof(obj)

# Open the HDF5 file
with h5py.File('weights-96-5.346523.hdf5', 'r') as file:
    groups = ['cg_id_0', 'cg_id_1', 'cg_id_2', 'cg_id_3', 'cg_id_4', 'cg_id_5', 
              'cg_reg_0', 'cg_reg_1', 'cg_reg_2', 'cg_reg_3', 'cg_reg_4', 'cg_reg_5', 
              'output_decoding']

    total_original_bias_size = 0
    total_original_kernel_size = 0
    total_quantized_bias_size = 0
    total_quantized_kernel_size = 0

    for group in groups:
        print(f"Processing group: {group}")
        subgroup_names = file[group].keys()

        for subgroup_name in subgroup_names:
            try:
                # Access the subgroup
                subgroup = file[group][subgroup_name]

                # Load the weights (bias and kernel)
                bias = subgroup['bias:0'][()]  # Load bias
                kernel = subgroup['kernel:0'][()]  # Load kernel

                # Apply Float16 quantization to the weights
                float16_bias = int8_quantization(bias)
                float16_kernel = int8_quantization(kernel)

                # Print the sizes and reduction factors
                original_bias_size = get_size(bias)
                original_kernel_size = get_size(kernel)
                quantized_bias_size = get_size(float16_bias)
                quantized_kernel_size = get_size(float16_kernel)

                # Accumulate the sizes
                total_original_bias_size += original_bias_size
                total_original_kernel_size += original_kernel_size
                total_quantized_bias_size += quantized_bias_size
                total_quantized_kernel_size += quantized_kernel_size

                print(f"Output with Float 16 Quantization")
                print(f"=====================================")
                print(f"Subgroup Name: {subgroup_name}")
                print(f"Original Bias Size: {original_bias_size} bytes")
                print(f"Original Kernel Size: {original_kernel_size} bytes")
                print(f"Quantized Bias Size: {quantized_bias_size} bytes")
                print(f"Quantized Kernel Size: {quantized_kernel_size} bytes")
                print(f"Reduction Factor for Bias: {original_bias_size / quantized_bias_size}x")
                print(f"Reduction Factor for Kernel: {original_kernel_size / quantized_kernel_size}x")
                print('======================')
                print()

                # Plot histograms
                float16_kernel_array_proto = tf.make_tensor_proto(float16_kernel[0])
                float16_kernel_array = tf.make_ndarray(float16_kernel_array_proto)

                plt.figure(figsize=(10, 4))

                plt.subplot(1, 2, 1)
                plt.hist(kernel.flatten(), bins=200, color='skyblue')
                plt.xlabel('Value')
                plt.ylabel('Frequency')
                plt.title('Histogram before quantization')

                plt.subplot(1, 2, 2)
                plt.hist(float16_kernel_array.flatten(), bins=100, color='skyblue')
                plt.xlabel('Value')
                plt.ylabel('Frequency')
                plt.title('Histogram after quantization')

                plt.tight_layout()
                plt.show()

            except KeyError as e:
                print(f"Skipping subgroup {subgroup_name} due to KeyError: {e}")
                continue

    # Calculate total sizes
    total_original_size = total_original_bias_size + total_original_kernel_size
    total_quantized_size = total_quantized_bias_size + total_quantized_kernel_size

    # Print the total sizes and reduction factor
    print(f"Total Original Bias Size: {total_original_bias_size} bytes")
    print(f"Total Original Kernel Size: {total_original_kernel_size} bytes")
    print(f"Total Quantized Bias Size: {total_quantized_bias_size} bytes")
    print(f"Total Quantized Kernel Size: {total_quantized_kernel_size} bytes")
    print(f"Total Original Size: {total_original_size} bytes")
    print(f"Total Quantized Size: {total_quantized_size} bytes")
    print(f"Reduction Factor: {total_original_size / total_quantized_size}x")
# Out:
# Processing group: cg_id_0
# Skipping subgroup cg_id_0 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# WARNING:tensorflow:From /home/shivam-raj/miniconda3/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1260: quantize_v2 (from tensorflow.python.ops.array_ops) is deprecated and will be removed after 2017-10-25.
# Instructions for updating:
# `tf.quantize_v2` is deprecated, please use `tf.quantization.quantize` instead.
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_0_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_0_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_0_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_0_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
# Processing group: cg_id_1
# Skipping subgroup cg_id_1 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_1_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_1_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_1_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_1_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
# Processing group: cg_id_2
# Skipping subgroup cg_id_2 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_2_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_2_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_2_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_2_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
# Processing group: cg_id_3
# Skipping subgroup cg_id_3 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_3_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_3_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_3_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_3_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
# Processing group: cg_id_4
# Skipping subgroup cg_id_4 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_4_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_4_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_4_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_4_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
# Processing group: cg_id_5
# Skipping subgroup cg_id_5 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_5_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_5_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_5_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_5_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
# Processing group: cg_reg_0
# Skipping subgroup cg_reg_0 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_0_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_0_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_0_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_0_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
# Processing group: cg_reg_1
# Skipping subgroup cg_reg_1 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_1_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_1_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_1_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_1_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
# Processing group: cg_reg_2
# Skipping subgroup cg_reg_2 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_2_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_2_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_2_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_2_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
# Processing group: cg_reg_3
# Skipping subgroup cg_reg_3 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_3_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_3_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_3_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_3_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
# Processing group: cg_reg_4
# Skipping subgroup cg_reg_4 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_4_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_4_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_4_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_4_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
# Processing group: cg_reg_5
# Skipping subgroup cg_reg_5 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_5_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_5_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_5_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_5_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
# Processing group: output_decoding
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_charge_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 131200 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 2050.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_charge_dense_1
# Original Bias Size: 124 bytes
# Original Kernel Size: 1664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 1.9375x
# Reduction Factor for Kernel: 26.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_cls_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 131200 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 2050.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_cls_dense_1
# Original Bias Size: 136 bytes
# Original Kernel Size: 3200 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 2.125x
# Reduction Factor for Kernel: 50.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_energy_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 268416 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 4194.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_energy_dense_1
# Original Bias Size: 116 bytes
# Original Kernel Size: 640 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 1.8125x
# Reduction Factor for Kernel: 10.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_eta_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 134272 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 2098.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_eta_dense_1
# Original Bias Size: 116 bytes
# Original Kernel Size: 640 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 1.8125x
# Reduction Factor for Kernel: 10.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_phi_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 134272 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 2098.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_phi_dense_1
# Original Bias Size: 120 bytes
# Original Kernel Size: 1152 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 1.875x
# Reduction Factor for Kernel: 18.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_pt_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 268416 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 4194.0x
# ======================
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_pt_dense_1
# Original Bias Size: 120 bytes
# Original Kernel Size: 1152 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 1.875x
# Reduction Factor for Kernel: 18.0x
# ======================
# Skipping subgroup output_decoding due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Total Original Bias Size: 25212 bytes
# Total Original Kernel Size: 2655232 bytes
# Total Quantized Bias Size: 3840 bytes
# Total Quantized Kernel Size: 3840 bytes
# Total Original Size: 2680444 bytes
# Total Quantized Size: 7680 bytes
# Reduction Factor: 349.0161458333333x

# %% [markdown]
# ## Plot for the Combining all of the files
# #### FP16 Qunatization

# %%
import h5py
import tensorflow as tf
import sys
import numpy as np
import matplotlib.pyplot as plt

# Define a function to apply Float16 quantization
def float16_quantization(weights):
    return tf.dtypes.cast(weights, tf.float16)

# Define a function to get the size of an object in bytes
def get_size(obj):
    return sys.getsizeof(obj)

# Open the HDF5 file
with h5py.File('weights-96-5.346523.hdf5', 'r') as file:
    groups = ['cg_id_0', 'cg_id_1', 'cg_id_2', 'cg_id_3', 'cg_id_4', 'cg_id_5', 
              'cg_reg_0', 'cg_reg_1', 'cg_reg_2', 'cg_reg_3', 'cg_reg_4', 'cg_reg_5', 
              'output_decoding']

    total_original_bias_size = 0
    total_original_kernel_size = 0
    total_quantized_bias_size = 0
    total_quantized_kernel_size = 0

    original_kernel_values = []
    quantized_kernel_values = []

    for group in groups:
        print(f"Processing group: {group}")
        subgroup_names = file[group].keys()

        for subgroup_name in subgroup_names:
            try:
                # Access the subgroup
                subgroup = file[group][subgroup_name]

                # Load the weights (bias and kernel)
                bias = subgroup['bias:0'][()]  # Load bias
                kernel = subgroup['kernel:0'][()]  # Load kernel

                # Apply Float16 quantization to the weights
                float16_bias = float16_quantization(bias)
                float16_kernel = float16_quantization(kernel)

                # Print the sizes and reduction factors
                original_bias_size = get_size(bias)
                original_kernel_size = get_size(kernel)
                quantized_bias_size = get_size(float16_bias)
                quantized_kernel_size = get_size(float16_kernel)

                # Accumulate the sizes
                total_original_bias_size += original_bias_size
                total_original_kernel_size += original_kernel_size
                total_quantized_bias_size += quantized_bias_size
                total_quantized_kernel_size += quantized_kernel_size

                print(f"Output with Float 16 Quantization")
                print(f"=====================================")
                print(f"Subgroup Name: {subgroup_name}")
                print(f"Original Bias Size: {original_bias_size} bytes")
                print(f"Original Kernel Size: {original_kernel_size} bytes")
                print(f"Quantized Bias Size: {quantized_bias_size} bytes")
                print(f"Quantized Kernel Size: {quantized_kernel_size} bytes")
                print(f"Reduction Factor for Bias: {original_bias_size / quantized_bias_size}x")
                print(f"Reduction Factor for Kernel: {original_kernel_size / quantized_kernel_size}x")
                print('======================')
                print()

                # Append kernel values for plotting
                original_kernel_values.extend(kernel.flatten())
                quantized_kernel_values.extend(float16_kernel.numpy().flatten())

            except KeyError as e:
                print(f"Skipping subgroup {subgroup_name} due to KeyError: {e}")
                continue

    # Calculate total sizes
    total_original_size = total_original_bias_size + total_original_kernel_size
    total_quantized_size = total_quantized_bias_size + total_quantized_kernel_size

    # Print the total sizes and reduction factor
    print(f"Total Original Bias Size: {total_original_bias_size} bytes")
    print(f"Total Original Kernel Size: {total_original_kernel_size} bytes")
    print(f"Total Quantized Bias Size: {total_quantized_bias_size} bytes")
    print(f"Total Quantized Kernel Size: {total_quantized_kernel_size} bytes")
    print(f"Total Original Size: {total_original_size} bytes")
    print(f"Total Quantized Size: {total_quantized_size} bytes")
    print(f"Reduction Factor: {total_original_size / total_quantized_size}x")

    # Plot the final combined histograms
    plt.figure(figsize=(10, 4))

    plt.subplot(1, 2, 1)
    plt.hist(original_kernel_values, bins=100, color='skyblue')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title('Combined Histogram before quantization')

    plt.subplot(1, 2, 2)
    plt.hist(quantized_kernel_values, bins=100, color='skyblue')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title('Combined Histogram after quantization')

    plt.tight_layout()
    plt.show()
# Out:
# Processing group: cg_id_0
# Skipping subgroup cg_id_0 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_0_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_0_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_0_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_0_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
#
# Processing group: cg_id_1
# Skipping subgroup cg_id_1 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_1_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_1_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_1_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_1_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
#
# Processing group: cg_id_2
# Skipping subgroup cg_id_2 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_2_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_2_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_2_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_2_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
#
# Processing group: cg_id_3
# Skipping subgroup cg_id_3 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_3_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_3_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_3_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_3_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
#
# Processing group: cg_id_4
# Skipping subgroup cg_id_4 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_4_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_4_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_4_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_4_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
#
# Processing group: cg_id_5
# Skipping subgroup cg_id_5 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_5_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_5_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_5_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_5_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
#
# Processing group: cg_reg_0
# Skipping subgroup cg_reg_0 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_0_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_0_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_0_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_0_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
#
# Processing group: cg_reg_1
# Skipping subgroup cg_reg_1 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_1_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_1_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_1_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_1_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
#
# Processing group: cg_reg_2
# Skipping subgroup cg_reg_2 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_2_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_2_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_2_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_2_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
#
# Processing group: cg_reg_3
# Skipping subgroup cg_reg_3 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_3_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_3_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_3_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_3_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
#
# Processing group: cg_reg_4
# Skipping subgroup cg_reg_4 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_4_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_4_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_4_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_4_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
#
# Processing group: cg_reg_5
# Skipping subgroup cg_reg_5 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_5_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 390.85714285714283x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_5_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_5_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 2.1904761904761907x
# Reduction Factor for Kernel: 98.28571428571429x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_5_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 195.8095238095238x
# ======================
#
# Processing group: output_decoding
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_charge_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 131200 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 780.952380952381x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_charge_dense_1
# Original Bias Size: 124 bytes
# Original Kernel Size: 1664 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 0.7380952380952381x
# Reduction Factor for Kernel: 9.904761904761905x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_cls_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 131200 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 780.952380952381x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_cls_dense_1
# Original Bias Size: 136 bytes
# Original Kernel Size: 3200 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 0.8095238095238095x
# Reduction Factor for Kernel: 19.047619047619047x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_energy_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 268416 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 1597.7142857142858x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_energy_dense_1
# Original Bias Size: 116 bytes
# Original Kernel Size: 640 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 0.6904761904761905x
# Reduction Factor for Kernel: 3.8095238095238093x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_eta_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 134272 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 799.2380952380952x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_eta_dense_1
# Original Bias Size: 116 bytes
# Original Kernel Size: 640 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 0.6904761904761905x
# Reduction Factor for Kernel: 3.8095238095238093x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_phi_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 134272 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 799.2380952380952x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_phi_dense_1
# Original Bias Size: 120 bytes
# Original Kernel Size: 1152 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 0.7142857142857143x
# Reduction Factor for Kernel: 6.857142857142857x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_pt_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 268416 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 3.7142857142857144x
# Reduction Factor for Kernel: 1597.7142857142858x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_pt_dense_1
# Original Bias Size: 120 bytes
# Original Kernel Size: 1152 bytes
# Quantized Bias Size: 168 bytes
# Quantized Kernel Size: 168 bytes
# Reduction Factor for Bias: 0.7142857142857143x
# Reduction Factor for Kernel: 6.857142857142857x
# ======================
#
# Skipping subgroup output_decoding due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Total Original Bias Size: 25212 bytes
# Total Original Kernel Size: 2655232 bytes
# Total Quantized Bias Size: 10080 bytes
# Total Quantized Kernel Size: 10080 bytes
# Total Original Size: 2680444 bytes
# Total Quantized Size: 20160 bytes
# Reduction Factor: 132.95853174603175x

# %% [markdown]
# #### FP8 Quantiation

# %%
import h5py
import tensorflow as tf
import sys
import numpy as np
import matplotlib.pyplot as plt

# Define a function to apply Int8 quantization
def int8_quantization(weights):
    min_val = tf.reduce_min(weights)
    max_val = tf.reduce_max(weights)
    quantized_weights = tf.quantization.quantize(weights, min_val, max_val, tf.qint8)
    return quantized_weights

# Define a function to get the size of an object in bytes
def get_size(obj):
    return sys.getsizeof(obj)

# Open the HDF5 file
with h5py.File('weights-96-5.346523.hdf5', 'r') as file:
    groups = ['cg_id_0', 'cg_id_1', 'cg_id_2', 'cg_id_3', 'cg_id_4', 'cg_id_5', 
              'cg_reg_0', 'cg_reg_1', 'cg_reg_2', 'cg_reg_3', 'cg_reg_4', 'cg_reg_5', 
              'output_decoding']

    total_original_bias_size = 0
    total_original_kernel_size = 0
    total_quantized_bias_size = 0
    total_quantized_kernel_size = 0

    original_kernel_values = []
    quantized_kernel_values = []

    for group in groups:
        print(f"Processing group: {group}")
        subgroup_names = file[group].keys()

        for subgroup_name in subgroup_names:
            try:
                # Access the subgroup
                subgroup = file[group][subgroup_name]

                # Load the weights (bias and kernel)
                bias = subgroup['bias:0'][()]  # Load bias
                kernel = subgroup['kernel:0'][()]  # Load kernel

                # Apply Float16 quantization to the weights
                float16_bias = int8_quantization(bias)
                float16_kernel = int8_quantization(kernel)

                # Print the sizes and reduction factors
                original_bias_size = get_size(bias)
                original_kernel_size = get_size(kernel)
                quantized_bias_size = get_size(float16_bias)
                quantized_kernel_size = get_size(float16_kernel)

                # Accumulate the sizes
                total_original_bias_size += original_bias_size
                total_original_kernel_size += original_kernel_size
                total_quantized_bias_size += quantized_bias_size
                total_quantized_kernel_size += quantized_kernel_size

                print(f"Output with Float 16 Quantization")
                print(f"=====================================")
                print(f"Subgroup Name: {subgroup_name}")
                print(f"Original Bias Size: {original_bias_size} bytes")
                print(f"Original Kernel Size: {original_kernel_size} bytes")
                print(f"Quantized Bias Size: {quantized_bias_size} bytes")
                print(f"Quantized Kernel Size: {quantized_kernel_size} bytes")
                print(f"Reduction Factor for Bias: {original_bias_size / quantized_bias_size}x")
                print(f"Reduction Factor for Kernel: {original_kernel_size / quantized_kernel_size}x")
                print('======================')
                print()

                # Append kernel values for plotting
                float16_kernel_array_proto = tf.make_tensor_proto(float16_kernel[0])
                float16_kernel_array = tf.make_ndarray(float16_kernel_array_proto)

            except KeyError as e:
                print(f"Skipping subgroup {subgroup_name} due to KeyError: {e}")
                continue

    # Calculate total sizes
    total_original_size = total_original_bias_size + total_original_kernel_size
    total_quantized_size = total_quantized_bias_size + total_quantized_kernel_size

    # Print the total sizes and reduction factor
    print(f"Total Original Bias Size: {total_original_bias_size} bytes")
    print(f"Total Original Kernel Size: {total_original_kernel_size} bytes")
    print(f"Total Quantized Bias Size: {total_quantized_bias_size} bytes")
    print(f"Total Quantized Kernel Size: {total_quantized_kernel_size} bytes")
    print(f"Total Original Size: {total_original_size} bytes")
    print(f"Total Quantized Size: {total_quantized_size} bytes")
    print(f"Reduction Factor: {total_original_size / total_quantized_size}x")

    # Plot the final combined histograms
    plt.figure(figsize=(10, 4))

    plt.subplot(1, 2, 1)
    plt.hist(original_kernel_values, bins=100, color='skyblue')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title('Combined Histogram before quantization')

    plt.subplot(1, 2, 2)
    plt.hist(quantized_kernel_values, bins=100, color='skyblue')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title('Combined Histogram after quantization')

    plt.tight_layout()
    plt.show()
# Out:
# Processing group: cg_id_0
# Skipping subgroup cg_id_0 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_0_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_0_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_0_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_0_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
#
# Processing group: cg_id_1
# Skipping subgroup cg_id_1 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_1_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_1_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_1_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_1_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
#
# Processing group: cg_id_2
# Skipping subgroup cg_id_2 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_2_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_2_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_2_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_2_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
#
# Processing group: cg_id_3
# Skipping subgroup cg_id_3 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_3_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_3_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_3_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_3_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
#
# Processing group: cg_id_4
# Skipping subgroup cg_id_4 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_4_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_4_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_4_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_4_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
#
# Processing group: cg_id_5
# Skipping subgroup cg_id_5 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_5_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_5_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_5_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_id_5_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
#
# Processing group: cg_reg_0
# Skipping subgroup cg_reg_0 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_0_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_0_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_0_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_0_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
#
# Processing group: cg_reg_1
# Skipping subgroup cg_reg_1 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_1_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_1_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_1_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_1_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
#
# Processing group: cg_reg_2
# Skipping subgroup cg_reg_2 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_2_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_2_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_2_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_2_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
#
# Processing group: cg_reg_3
# Skipping subgroup cg_reg_3 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_3_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_3_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_3_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_3_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
#
# Processing group: cg_reg_4
# Skipping subgroup cg_reg_4 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_4_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_4_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_4_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_4_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
#
# Processing group: cg_reg_5
# Skipping subgroup cg_reg_5 due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_5_ffn_dist_dense_0
# Original Bias Size: 368 bytes
# Original Kernel Size: 65664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 1026.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_5_ffn_dist_dense_1
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_5_ffn_dist_dense_2
# Original Bias Size: 368 bytes
# Original Kernel Size: 16512 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 5.75x
# Reduction Factor for Kernel: 258.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: cg_reg_5_ffn_dist_dense_3
# Original Bias Size: 624 bytes
# Original Kernel Size: 32896 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 514.0x
# ======================
#
# Processing group: output_decoding
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_charge_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 131200 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 2050.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_charge_dense_1
# Original Bias Size: 124 bytes
# Original Kernel Size: 1664 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 1.9375x
# Reduction Factor for Kernel: 26.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_cls_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 131200 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 2050.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_cls_dense_1
# Original Bias Size: 136 bytes
# Original Kernel Size: 3200 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 2.125x
# Reduction Factor for Kernel: 50.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_energy_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 268416 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 4194.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_energy_dense_1
# Original Bias Size: 116 bytes
# Original Kernel Size: 640 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 1.8125x
# Reduction Factor for Kernel: 10.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_eta_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 134272 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 2098.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_eta_dense_1
# Original Bias Size: 116 bytes
# Original Kernel Size: 640 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 1.8125x
# Reduction Factor for Kernel: 10.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_phi_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 134272 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 2098.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_phi_dense_1
# Original Bias Size: 120 bytes
# Original Kernel Size: 1152 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 1.875x
# Reduction Factor for Kernel: 18.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_pt_dense_0
# Original Bias Size: 624 bytes
# Original Kernel Size: 268416 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 9.75x
# Reduction Factor for Kernel: 4194.0x
# ======================
#
# Output with Float 16 Quantization
# =====================================
# Subgroup Name: ffn_pt_dense_1
# Original Bias Size: 120 bytes
# Original Kernel Size: 1152 bytes
# Quantized Bias Size: 64 bytes
# Quantized Kernel Size: 64 bytes
# Reduction Factor for Bias: 1.875x
# Reduction Factor for Kernel: 18.0x
# ======================
#
# Skipping subgroup output_decoding due to KeyError: "Unable to open object (object 'bias:0' doesn't exist)"
# Total Original Bias Size: 25212 bytes
# Total Original Kernel Size: 2655232 bytes
# Total Quantized Bias Size: 3840 bytes
# Total Quantized Kernel Size: 3840 bytes
# Total Original Size: 2680444 bytes
# Total Quantized Size: 7680 bytes
# Reduction Factor: 349.0161458333333x

# %% [markdown]
# Issues:-
#
#     1. I do not think, the output coming is correct as you can see the output plot either there are no differences or there are no any plots.
#     2. Memory might not be defined properly
