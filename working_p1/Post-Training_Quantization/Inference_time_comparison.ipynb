# %%
import matplotlib.pyplot as plt

# Data for dynamic range quantization
quantized_data = {
    "cpu 4 threads (xnnpack)": {
        "avg_time": 103222,
        "std_dev": 7300
    },
    "cpu 2 threads": {
        "avg_time": 107997,
        "std_dev": 2109
    },
    "cpu 1 threads": {
        "avg_time": 111545,
        "std_dev": 1930
    },
    "cpu 2 threads (xnnpack)": {
        "avg_time": 112655,
        "std_dev": 1723
    },
    "cpu 1 threads (xnnpack)": {
        "avg_time": 114236,
        "std_dev": 1812
    },
    "gpu-default": {
        "avg_time": 124948,
        "std_dev": 2816
    },
    "cpu 4 threads": {
        "avg_time": 127433,
        "std_dev": 8085
    }
}

# Data for unquantized model
unquantized_data = {
    "cpu 4 threads": {
        "avg_time": 32342.5,
        "std_dev": 4581
    },
    "cpu 4 threads (xnnpack)": {
        "avg_time": 36086,
        "std_dev": 3203
    },
    "cpu 2 threads": {
        "avg_time": 39234.3,
        "std_dev": 818
    },
    "cpu 2 threads (xnnpack)": {
        "avg_time": 45355.6,
        "std_dev": 13556
    },
    "cpu 1 threads (xnnpack)": {
        "avg_time": 62408.6,
        "std_dev": 1483
    },
    "cpu 1 threads": {
        "avg_time": 66269.7,
        "std_dev": 2126
    },
    "gpu-default": {
        "avg_time": 66347.7,
        "std_dev": 2466
    }
}

def plot_data(data, title):
    configs = list(data.keys())
    avg_times = [data[config]["avg_time"] for config in configs]
    std_devs = [data[config]["std_dev"] for config in configs]

    plt.figure(figsize=(12, 6))
    plt.barh(configs, avg_times, xerr=std_devs, capsize=5, color='skyblue')
    plt.xlabel('Average Inference Time (microseconds)')
    plt.ylabel('Configuration')
    plt.title(title)
    plt.grid(axis='x')
    plt.tight_layout()
    plt.show()

plot_data(quantized_data, 'Dynamic Range Quantization')
plot_data(unquantized_data, 'Unquantized Model')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for dynamic range quantization
quantized_data = {
    "cpu 4 threads (xnnpack)": {
        "avg_time": 103222,
        "std_dev": 7300
    },
    "cpu 2 threads": {
        "avg_time": 107997,
        "std_dev": 2109
    },
    "cpu 1 threads": {
        "avg_time": 111545,
        "std_dev": 1930
    },
    "cpu 2 threads (xnnpack)": {
        "avg_time": 112655,
        "std_dev": 1723
    },
    "cpu 1 threads (xnnpack)": {
        "avg_time": 114236,
        "std_dev": 1812
    },
    "gpu-default": {
        "avg_time": 124948,
        "std_dev": 2816
    },
    "cpu 4 threads": {
        "avg_time": 127433,
        "std_dev": 8085
    }
}

# Data for unquantized model
unquantized_data = {
    "cpu 4 threads": {
        "avg_time": 32342.5,
        "std_dev": 4581
    },
    "cpu 4 threads (xnnpack)": {
        "avg_time": 36086,
        "std_dev": 3203
    },
    "cpu 2 threads": {
        "avg_time": 39234.3,
        "std_dev": 818
    },
    "cpu 2 threads (xnnpack)": {
        "avg_time": 45355.6,
        "std_dev": 13556
    },
    "cpu 1 threads (xnnpack)": {
        "avg_time": 62408.6,
        "std_dev": 1483
    },
    "cpu 1 threads": {
        "avg_time": 66269.7,
        "std_dev": 2126
    },
    "gpu-default": {
        "avg_time": 66347.7,
        "std_dev": 2466
    }
}

def plot_data(data1, data2, title):
    configs = list(data1.keys())
    avg_times1 = [data1[config]["avg_time"] for config in configs]
    avg_times2 = [data2[config]["avg_time"] for config in configs]
    std_devs1 = [data1[config]["std_dev"] for config in configs]
    std_devs2 = [data2[config]["std_dev"] for config in configs]

    bar_width = 0.35
    index = np.arange(len(configs))

    plt.figure(figsize=(12, 6))
    plt.bar(index, avg_times1, bar_width, label='Quantized', color='skyblue', yerr=std_devs1, capsize=5)
    plt.bar(index + bar_width, avg_times2, bar_width, label='Unquantized', color='salmon', yerr=std_devs2, capsize=5)
    plt.xlabel('Configuration')
    plt.ylabel('Average Inference Time (microseconds)')
    plt.title(title)
    plt.xticks(index + bar_width / 2, configs, rotation=45, ha='right')
    plt.legend()
    plt.tight_layout()
    plt.show()

plot_data(quantized_data, unquantized_data, 'Comparison of Quantized and Unquantized Models')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for dynamic range quantization
quantized_data = {
    "cpu 4 threads (xnnpack)": {
        "avg_time": 103222,
        "std_dev": 7300
    },
    "cpu 2 threads": {
        "avg_time": 107997,
        "std_dev": 2109
    },
    "cpu 1 threads": {
        "avg_time": 111545,
        "std_dev": 1930
    },
    "cpu 2 threads (xnnpack)": {
        "avg_time": 112655,
        "std_dev": 1723
    },
    "cpu 1 threads (xnnpack)": {
        "avg_time": 114236,
        "std_dev": 1812
    },
    "gpu-default": {
        "avg_time": 124948,
        "std_dev": 2816
    },
    "cpu 4 threads": {
        "avg_time": 127433,
        "std_dev": 8085
    }
}

# Data for unquantized model
unquantized_data = {
    "cpu 4 threads": {
        "avg_time": 32342.5,
        "std_dev": 4581
    },
    "cpu 4 threads (xnnpack)": {
        "avg_time": 36086,
        "std_dev": 3203
    },
    "cpu 2 threads": {
        "avg_time": 39234.3,
        "std_dev": 818
    },
    "cpu 2 threads (xnnpack)": {
        "avg_time": 45355.6,
        "std_dev": 13556
    },
    "cpu 1 threads (xnnpack)": {
        "avg_time": 62408.6,
        "std_dev": 1483
    },
    "cpu 1 threads": {
        "avg_time": 66269.7,
        "std_dev": 2126
    },
    "gpu-default": {
        "avg_time": 66347.7,
        "std_dev": 2466
    }
}

def calculate_reduction(quantized_data, unquantized_data):
    reduction_data = {}
    for config in quantized_data:
        reduction = quantized_data[config]["avg_time"] - unquantized_data[config]["avg_time"]
        reduction_data[config] = reduction
    return reduction_data

def plot_data(quantized_data, unquantized_data, title):
    configs = list(quantized_data.keys())
    avg_times1 = [quantized_data[config]["avg_time"] for config in configs]
    avg_times2 = [unquantized_data[config]["avg_time"] for config in configs]
    std_devs1 = [quantized_data[config]["std_dev"] for config in configs]
    std_devs2 = [unquantized_data[config]["std_dev"] for config in configs]
    
    reduction_data = calculate_reduction(quantized_data, unquantized_data)
    reductions = [reduction_data[config] for config in configs]

    bar_width = 0.35
    index = np.arange(len(configs))

    plt.figure(figsize=(12, 6))
    plt.bar(index, avg_times1, bar_width, label='Quantized', color='skyblue', yerr=std_devs1, capsize=5)
    plt.bar(index + bar_width, avg_times2, bar_width, label='Unquantized', color='salmon', yerr=std_devs2, capsize=5)
    plt.xlabel('Configuration')
    plt.ylabel('Average Inference Time (microseconds)')
    plt.title(title)
    plt.xticks(index + bar_width / 2, configs, rotation=45, ha='right')
    plt.legend()
    for i in range(len(configs)):
        plt.text(index[i] + bar_width / 2, max(avg_times1[i], avg_times2[i]), f'{reductions[i]:.2f}', ha='center', va='bottom', color='black')
    plt.tight_layout()
    plt.show()

plot_data(quantized_data, unquantized_data, 'Comparison of Quantized and Unquantized Models')

# %%
import matplotlib.pyplot as plt

# Data for dynamic range quantization
dynamic_range_quantization = {
    "cpu 4 threads (xnnpack)": 103222,
    "cpu 2 threads": 107997,
    "cpu 1 threads": 111545,
    "cpu 2 threads (xnnpack)": 112655,
    "cpu 1 threads (xnnpack)": 114236,
    "gpu-default": 124948,
    "cpu 4 threads": 127433
}

# Data for unquantized model
unquantized_model = {
    "cpu 4 threads": 32342.5,
    "cpu 4 threads (xnnpack)": 36086,
    "cpu 2 threads": 39234.3,
    "cpu 2 threads (xnnpack)": 45355.6,
    "cpu 1 threads (xnnpack)": 62408.6,
    "cpu 1 threads": 66269.7,
    "gpu-default": 66347.7
}

# Data for float16 quantization
float16_quantization = {
    "cpu 4 threads": 42406.2,
    "cpu 2 threads (xnnpack)": 43099.5,
    "cpu 4 threads (xnnpack)": 46902.8,
    "cpu 2 threads": 50807.4,
    "cpu 1 threads": 56779,
    "cpu 1 threads (xnnpack)": 61025.6,
    "gpu-default": 66064.2
}

def plot_comparison(data, title):
    configs = list(data.keys())
    avg_times = list(data.values())

    plt.figure(figsize=(12, 6))
    plt.barh(configs, avg_times, color='skyblue')
    plt.xlabel('Average Inference Time (microseconds)')
    plt.ylabel('Configuration')
    plt.title(title)
    plt.grid(axis='x')
    plt.tight_layout()
    plt.show()

plot_comparison(dynamic_range_quantization, 'Dynamic Range Quantization')
plot_comparison(unquantized_model, 'Unquantized Model')
plot_comparison(float16_quantization, 'Float16 Quantization')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for dynamic range quantization
dynamic_range_quantization = {
    "cpu 4 threads (xnnpack)": 103222,
    "cpu 2 threads": 107997,
    "cpu 1 threads": 111545,
    "cpu 2 threads (xnnpack)": 112655,
    "cpu 1 threads (xnnpack)": 114236,
    "gpu-default": 124948,
    "cpu 4 threads": 127433
}

# Data for unquantized model
unquantized_model = {
    "cpu 4 threads": 32342.5,
    "cpu 4 threads (xnnpack)": 36086,
    "cpu 2 threads": 39234.3,
    "cpu 2 threads (xnnpack)": 45355.6,
    "cpu 1 threads (xnnpack)": 62408.6,
    "cpu 1 threads": 66269.7,
    "gpu-default": 66347.7
}

# Data for float16 quantization
float16_quantization = {
    "cpu 4 threads": 42406.2,
    "cpu 2 threads (xnnpack)": 43099.5,
    "cpu 4 threads (xnnpack)": 46902.8,
    "cpu 2 threads": 50807.4,
    "cpu 1 threads": 56779,
    "cpu 1 threads (xnnpack)": 61025.6,
    "gpu-default": 66064.2
}

def plot_comparison(data1, data2, data3, title):
    configs = list(data1.keys())
    avg_times1 = list(data1.values())
    avg_times2 = list(data2.values())
    avg_times3 = list(data3.values())

    bar_width = 0.25
    index = np.arange(len(configs))

    plt.figure(figsize=(12, 6))
    plt.bar(index, avg_times1, bar_width, label='Dynamic Range Quantization', color='skyblue')
    plt.bar(index + bar_width, avg_times2, bar_width, label='Unquantized Model', color='salmon')
    plt.bar(index + 2 * bar_width, avg_times3, bar_width, label='Float16 Quantization', color='lightgreen')
    plt.xlabel('Configuration')
    plt.ylabel('Average Inference Time (microseconds)')
    plt.title(title)
    plt.xticks(index + bar_width, configs, rotation=45, ha='right')
    plt.legend()
    plt.tight_layout()
    plt.show()

plot_comparison(dynamic_range_quantization, unquantized_model, float16_quantization, 'Comparison of Quantization Techniques')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for dynamic range quantization
dynamic_range_quantization = {
    "cpu 4 threads (xnnpack)": 103222,
    "cpu 2 threads": 107997,
    "cpu 1 threads": 111545,
    "cpu 2 threads (xnnpack)": 112655,
    "cpu 1 threads (xnnpack)": 114236,
    "gpu-default": 124948,
    "cpu 4 threads": 127433
}

# Data for unquantized model
unquantized_model = {
    "cpu 4 threads": 32342.5,
    "cpu 4 threads (xnnpack)": 36086,
    "cpu 2 threads": 39234.3,
    "cpu 2 threads (xnnpack)": 45355.6,
    "cpu 1 threads (xnnpack)": 62408.6,
    "cpu 1 threads": 66269.7,
    "gpu-default": 66347.7
}

# Data for float16 quantization
float16_quantization = {
    "cpu 4 threads": 42406.2,
    "cpu 2 threads (xnnpack)": 43099.5,
    "cpu 4 threads (xnnpack)": 46902.8,
    "cpu 2 threads": 50807.4,
    "cpu 1 threads": 56779,
    "cpu 1 threads (xnnpack)": 61025.6,
    "gpu-default": 66064.2
}

def plot_comparison(data1, data2, data3, title):
    configs = list(data1.keys())
    avg_times1 = list(data1.values())
    avg_times2 = list(data2.values())
    avg_times3 = list(data3.values())

    bar_width = 0.25
    index = np.arange(len(configs))

    plt.figure(figsize=(12, 6))
    plt.bar(index, avg_times1, bar_width, label='Dynamic Range Quantization', color='skyblue')
    plt.bar(index + bar_width, avg_times3, bar_width, label='Float16 Quantization', color='lightgreen')
    plt.bar(index + 2 * bar_width, avg_times2, bar_width, label='Unquantized Model', color='salmon')
    plt.xlabel('Configuration')
    plt.ylabel('Average Inference Time (microseconds)')
    plt.title(title)
    plt.xticks(index + bar_width, configs, rotation=45, ha='right')
    plt.legend(loc="best")
    plt.tight_layout()
    plt.savefig("output.png")
    plt.show()

plot_comparison(dynamic_range_quantization, unquantized_model, float16_quantization, 'Comparison of Quantization Techniques')

# %%
import matplotlib.pyplot as plt
import numpy as np

unquantized_avg_times = {
    "cpu 4 threads": 33904.9,
    "cpu 4 threads (xnnpack)": 39220.2,
    "cpu 2 threads (xnnpack)": 41921.3,
    "cpu 2 threads": 44573,
    "gpu-default": 57705.5,
    "cpu 1 threads (xnnpack)": 61070,
    "cpu 1 threads": 62723.4
}

fp16_avg_times = {
    "cpu 4 threads (xnnpack)": 34673.5,
    "cpu 4 threads": 39937.7,
    "cpu 2 threads": 48602.2,
    "cpu 2 threads (xnnpack)": 55170.9,
    "cpu 1 threads (xnnpack)": 62946,
    "gpu-default": 64018.8,
    "cpu 1 threads": 64855.8
}

dynamic_range_avg_times = {
    "cpu 1 threads (xnnpack)": 98936.8,
    "cpu 4 threads (xnnpack)": 107331,
    "cpu 2 threads (xnnpack)": 107661,
    "cpu 2 threads": 115431,
    "cpu 1 threads": 121102,
    "gpu-default": 121437,
    "cpu 4 threads": 128087
}

def plot_inference_times(unquantized_data, fp16_data, dynamic_range_data):
    configs = list(unquantized_data.keys())
    index = np.arange(len(configs))
    bar_width = 0.25

    plt.figure(figsize=(14, 8))

    plt.bar(index - bar_width, list(unquantized_data.values()), bar_width, label='Unquantized Model')
    plt.bar(index, list(fp16_data.values()), bar_width, label='FP16 Quantization')
    plt.bar(index + bar_width, list(dynamic_range_data.values()), bar_width, label='Dynamic Range Quantization')

    plt.xlabel('Configuration')
    plt.ylabel('Average Inference Time (microseconds)')
    plt.title('Comparison of Inference Times for Unquantized Model vs. Quantized Versions')
    plt.xticks(index, configs, rotation=45, ha='right')
    plt.legend()
    plt.tight_layout()
    plt.show()

plot_inference_times(unquantized_avg_times, fp16_avg_times, dynamic_range_avg_times)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for unquantized model
unquantized_avg_times = {
    "cpu 4 threads": 33904.9,
    "cpu 4 threads (xnnpack)": 39220.2,
    "cpu 2 threads (xnnpack)": 41921.3,
    "cpu 2 threads": 44573,
    "gpu-default": 57705.5,
    "cpu 1 threads (xnnpack)": 61070,
    "cpu 1 threads": 62723.4
}

# Data for FP16 quantization
fp16_avg_times = {
    "cpu 4 threads (xnnpack)": 34673.5,
    "cpu 4 threads": 39937.7,
    "cpu 2 threads": 48602.2,
    "cpu 2 threads (xnnpack)": 55170.9,
    "cpu 1 threads (xnnpack)": 62946,
    "gpu-default": 64018.8,
    "cpu 1 threads": 64855.8
}

# Data for dynamic range quantization
dynamic_range_avg_times = {
    "cpu 1 threads (xnnpack)": 98936.8,
    "cpu 4 threads (xnnpack)": 107331,
    "cpu 2 threads (xnnpack)": 107661,
    "cpu 2 threads": 115431,
    "cpu 1 threads": 121102,
    "gpu-default": 121437,
    "cpu 4 threads": 128087
}

def calculate_speedup_factor(unquantized_data, quantized_data):
    speedup_factors = {}
    for config, unquantized_time in unquantized_data.items():
        quantized_time = quantized_data.get(config)
        if quantized_time is not None:
            speedup_factors[config] = quantized_time / unquantized_time
    return speedup_factors

def plot_speedup_factor(speedup_factors):
    configs = list(speedup_factors.keys())
    speedups = list(speedup_factors.values())

    plt.figure(figsize=(10, 6))
    plt.plot(configs, speedups, marker='o', linestyle='-')
    plt.xlabel('Configuration')
    plt.ylabel('Speedup Factor')
    plt.title('Speedup Factor of Unquantized Model vs. Quantized Versions')
    plt.xticks(rotation=45, ha='right')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

#  speedup factors
fp16_speedup_factors = calculate_speedup_factor(unquantized_avg_times, fp16_avg_times)
int8_speedup_factors = calculate_speedup_factor(unquantized_avg_times, dynamic_range_avg_times)


plot_speedup_factor(fp16_speedup_factors)
plot_speedup_factor(int8_speedup_factors)

# %% [markdown]
# # Throughput

# %%
import matplotlib.pyplot as plt

# Data for unquantized model
unquantized_avg_times = {
    "cpu 4 threads": 33904.9,
    "cpu 4 threads (xnnpack)": 39220.2,
    "cpu 2 threads (xnnpack)": 41921.3,
    "cpu 2 threads": 44573,
    "gpu-default": 57705.5,
    "cpu 1 threads (xnnpack)": 61070,
    "cpu 1 threads": 62723.4
}

# Data for FP16 quantization
fp16_avg_times = {
    "cpu 4 threads (xnnpack)": 34673.5,
    "cpu 4 threads": 39937.7,
    "cpu 2 threads": 48602.2,
    "cpu 2 threads (xnnpack)": 55170.9,
    "cpu 1 threads (xnnpack)": 62946,
    "gpu-default": 64018.8,
    "cpu 1 threads": 64855.8
}

# Data for dynamic range quantization
dynamic_range_avg_times = {
    "cpu 1 threads (xnnpack)": 98936.8,
    "cpu 4 threads (xnnpack)": 107331,
    "cpu 2 threads (xnnpack)": 107661,
    "cpu 2 threads": 115431,
    "cpu 1 threads": 121102,
    "gpu-default": 121437,
    "cpu 4 threads": 128087
}

def calculate_throughput(avg_times):
    throughput = {config: 1 / time for config, time in avg_times.items()}
    return throughput

def plot_throughput(throughput, title):
    plt.figure(figsize=(10, 6))
    plt.barh(list(throughput.keys()), list(throughput.values()), color='skyblue')
    plt.xlabel('Throughput (samples/second)')
    plt.ylabel('Configuration')
    plt.title(title)
    plt.gca().invert_yaxis()
    plt.tight_layout()
    plt.show()

# Calculate throughput for unquantized model
unquantized_throughput = calculate_throughput(unquantized_avg_times)
plot_throughput(unquantized_throughput, 'Throughput for Unquantized Model')

# Calculate throughput for FP16 quantization
fp16_throughput = calculate_throughput(fp16_avg_times)
plot_throughput(fp16_throughput, 'Throughput for FP16 Quantization')

# Calculate throughput for dynamic range quantization
dynamic_range_throughput = calculate_throughput(dynamic_range_avg_times)
plot_throughput(dynamic_range_throughput, 'Throughput for Dynamic Range Quantization')

# %%
import matplotlib.pyplot as plt

# Data for unquantized model
unquantized_avg_times = {
    "cpu 4 threads": 33904.9,
    "cpu 4 threads (xnnpack)": 39220.2,
    "cpu 2 threads (xnnpack)": 41921.3,
    "cpu 2 threads": 44573,
    "gpu-default": 57705.5,
    "cpu 1 threads (xnnpack)": 61070,
    "cpu 1 threads": 62723.4
}

# Data for FP16 quantization
fp16_avg_times = {
    "cpu 4 threads (xnnpack)": 34673.5,
    "cpu 4 threads": 39937.7,
    "cpu 2 threads": 48602.2,
    "cpu 2 threads (xnnpack)": 55170.9,
    "cpu 1 threads (xnnpack)": 62946,
    "gpu-default": 64018.8,
    "cpu 1 threads": 64855.8
}

# Data for dynamic range quantization
dynamic_range_avg_times = {
    "cpu 1 threads (xnnpack)": 98936.8,
    "cpu 4 threads (xnnpack)": 107331,
    "cpu 2 threads (xnnpack)": 107661,
    "cpu 2 threads": 115431,
    "cpu 1 threads": 121102,
    "gpu-default": 121437,
    "cpu 4 threads": 128087
}

def calculate_throughput(avg_times):
    throughput = {config: 1 / time for config, time in avg_times.items()}
    return throughput

def plot_throughput(throughput, label):
    plt.barh(list(throughput.keys()), list(throughput.values()), label=label)

# Calculate throughput for each model
unquantized_throughput = calculate_throughput(unquantized_avg_times)
fp16_throughput = calculate_throughput(fp16_avg_times)
dynamic_range_throughput = calculate_throughput(dynamic_range_avg_times)

# Plot all throughput data on the same plot
plt.figure(figsize=(10, 6))
plot_throughput(unquantized_throughput, label='Unquantized Model')
plot_throughput(fp16_throughput, label='FP16 Quantization')
plot_throughput(dynamic_range_throughput, label='Dynamic Range Quantization')
plt.xlabel('Throughput (samples/second)')
plt.ylabel('Configuration')
plt.title('Comparison of Throughput Across Different Quantization Techniques')
plt.legend()
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for unquantized model
unquantized_avg_times = {
    "cpu 4 threads": 33904.9,
    "cpu 4 threads (xnnpack)": 39220.2,
    "cpu 2 threads (xnnpack)": 41921.3,
    "cpu 2 threads": 44573,
    "gpu-default": 57705.5,
    "cpu 1 threads (xnnpack)": 61070,
    "cpu 1 threads": 62723.4
}

# Data for FP16 quantization
fp16_avg_times = {
    "cpu 4 threads (xnnpack)": 34673.5,
    "cpu 4 threads": 39937.7,
    "cpu 2 threads": 48602.2,
    "cpu 2 threads (xnnpack)": 55170.9,
    "cpu 1 threads (xnnpack)": 62946,
    "gpu-default": 64018.8,
    "cpu 1 threads": 64855.8
}

# Data for dynamic range quantization
dynamic_range_avg_times = {
    "cpu 1 threads (xnnpack)": 98936.8,
    "cpu 4 threads (xnnpack)": 107331,
    "cpu 2 threads (xnnpack)": 107661,
    "cpu 2 threads": 115431,
    "cpu 1 threads": 121102,
    "gpu-default": 121437,
    "cpu 4 threads": 128087
}

def calculate_throughput(avg_times):
    throughput = {config: 1 / time for config, time in avg_times.items()}
    return throughput

def plot_throughput(throughput, label, marker):
    plt.plot(list(throughput.keys()), list(throughput.values()), marker=marker, label=label)

# Calculate throughput for each model
unquantized_throughput = calculate_throughput(unquantized_avg_times)
fp16_throughput = calculate_throughput(fp16_avg_times)
dynamic_range_throughput = calculate_throughput(dynamic_range_avg_times)

# Plot throughput data on the same plot
plt.figure(figsize=(10, 6))
plot_throughput(unquantized_throughput, label='Unquantized Model', marker='o')
plot_throughput(fp16_throughput, label='FP16 Quantization', marker='s')
plot_throughput(dynamic_range_throughput, label='Dynamic Range Quantization', marker='^')
plt.xlabel('Configuration')
plt.ylabel('Throughput (samples/second)')
plt.title(' Throughput Comparison')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for unquantized model
unquantized_avg_times = {
    "cpu 4 threads": 33904.9,
    "cpu 4 threads (xnnpack)": 39220.2,
    "cpu 2 threads (xnnpack)": 41921.3,
    "cpu 2 threads": 44573,
    "gpu-default": 57705.5,
    "cpu 1 threads (xnnpack)": 61070,
    "cpu 1 threads": 62723.4
}

# Data for FP16 quantization
fp16_avg_times = {
    "cpu 4 threads (xnnpack)": 34673.5,
    "cpu 4 threads": 39937.7,
    "cpu 2 threads": 48602.2,
    "cpu 2 threads (xnnpack)": 55170.9,
    "cpu 1 threads (xnnpack)": 62946,
    "gpu-default": 64018.8,
    "cpu 1 threads": 64855.8
}

# Data for dynamic range quantization
dynamic_range_avg_times = {
    "cpu 1 threads (xnnpack)": 98936.8,
    "cpu 4 threads (xnnpack)": 107331,
    "cpu 2 threads (xnnpack)": 107661,
    "cpu 2 threads": 115431,
    "cpu 1 threads": 121102,
    "gpu-default": 121437,
    "cpu 4 threads": 128087
}

def calculate_throughput(avg_times):
    throughput = {config: 1 / time for config, time in avg_times.items()}
    return throughput

def normalize_throughput(throughput):
    max_throughput = max(throughput.values())
    normalized_throughput = {config: tp / max_throughput for config, tp in throughput.items()}
    return normalized_throughput

def plot_normalized_throughput(throughput, label, linestyle):
    plt.plot(list(throughput.keys()), list(throughput.values()), label=label, linestyle=linestyle)

# Calculate and normalize throughput for each model
unquantized_throughput = normalize_throughput(calculate_throughput(unquantized_avg_times))
fp16_throughput = normalize_throughput(calculate_throughput(fp16_avg_times))
dynamic_range_throughput = normalize_throughput(calculate_throughput(dynamic_range_avg_times))

# Plot normalized throughput data on the same plot
plt.figure(figsize=(10, 6))
plot_normalized_throughput(unquantized_throughput, label='Unquantized Model', linestyle='-')
plot_normalized_throughput(fp16_throughput, label='FP16 Quantization', linestyle='--')
plot_normalized_throughput(dynamic_range_throughput, label='Dynamic Range Quantization', linestyle=':')
plt.xlabel('Configuration')
plt.ylabel('Normalized Throughput')
plt.title('Comparison of Normalized Throughput Across Different Quantization Techniques')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for unquantized model
unquantized_avg_times = {
    "cpu 4 threads": 33904.9,
    "cpu 4 threads (xnnpack)": 39220.2,
    "cpu 2 threads (xnnpack)": 41921.3,
    "cpu 2 threads": 44573,
    "gpu-default": 57705.5,
    "cpu 1 threads (xnnpack)": 61070,
    "cpu 1 threads": 62723.4
}

# Data for FP16 quantization
fp16_avg_times = {
    "cpu 4 threads (xnnpack)": 34673.5,
    "cpu 4 threads": 39937.7,
    "cpu 2 threads": 48602.2,
    "cpu 2 threads (xnnpack)": 55170.9,
    "cpu 1 threads (xnnpack)": 62946,
    "gpu-default": 64018.8,
    "cpu 1 threads": 64855.8
}

# Data for dynamic range quantization
dynamic_range_avg_times = {
    "cpu 1 threads (xnnpack)": 98936.8,
    "cpu 4 threads (xnnpack)": 107331,
    "cpu 2 threads (xnnpack)": 107661,
    "cpu 2 threads": 115431,
    "cpu 1 threads": 121102,
    "gpu-default": 121437,
    "cpu 4 threads": 128087
}

# Model size data
unquantized_model_size = 22468840
fp16_model_size = 11428456
dynamic_range_model_size = 6126520

def calculate_throughput(avg_times):
    throughput = {config: 1 / time for config, time in avg_times.items()}
    return throughput

def normalize_throughput(throughput):
    max_throughput = max(throughput.values())
    normalized_throughput = {config: tp / max_throughput for config, tp in throughput.items()}
    return normalized_throughput

# Calculate and normalize throughput for each model
unquantized_throughput = normalize_throughput(calculate_throughput(unquantized_avg_times))
fp16_throughput = normalize_throughput(calculate_throughput(fp16_avg_times))
dynamic_range_throughput = normalize_throughput(calculate_throughput(dynamic_range_avg_times))

# Plot normalized throughput data on the original plot
plt.figure(figsize=(10, 6))
plt.plot(list(unquantized_throughput.keys()), list(unquantized_throughput.values()), label='Unquantized Model', linestyle='-')
plt.plot(list(fp16_throughput.keys()), list(fp16_throughput.values()), label='FP16 Quantization', linestyle='--')
plt.plot(list(dynamic_range_throughput.keys()), list(dynamic_range_throughput.values()), label='Dynamic Range Quantization', linestyle=':')
plt.xlabel('Configuration')
plt.ylabel('Normalized Throughput')
plt.title('Comparison of Normalized Throughput Across Different Quantization Techniques')
plt.legend()
plt.grid(True)

# Add a separate subplot for model size comparison
plt.figure(figsize=(10, 4))
model_sizes = [unquantized_model_size, fp16_model_size, dynamic_range_model_size]
labels = ['Unquantized', 'FP16 Quantization', 'Dynamic Range Quantization']
plt.bar(labels, model_sizes, color=['blue', 'orange', 'green'])
plt.xlabel('Quantization Technique')
plt.ylabel('Model Size (bytes)')
plt.title('Comparison of Model Sizes Across Different Quantization Techniques')

plt.show()

# %%
# Add a separate subplot for model size comparison
plt.figure(figsize=(10, 4))
model_sizes = [unquantized_model_size, fp16_model_size, dynamic_range_model_size]
labels = ['Unquantized', 'FP16 Quantization', 'Dynamic Range Quantization']
plt.bar(labels, model_sizes, color=['blue', 'orange', 'green'])
plt.xlabel('Quantization Technique')
plt.ylabel('Model Size (bytes)')
plt.title('Comparison of Model Sizes ')
plt.savefig('size_Comparison.png')
plt.show()
